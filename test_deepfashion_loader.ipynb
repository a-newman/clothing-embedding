# %%
# %load ~/.firstcell.py
# %load_ext autoreload
# %autoreload 2

import json
import pandas as pd
import numpy as np 
from PIL import Image
import matplotlib.pyplot as plt 
import cv2
import os 
import sys
import csv
from IPython.display import Video, HTML

sys.path.insert(0, os.path.expanduser("~"))
from python_helpers import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import random
from data_loader import DeepFashionContrastiveLoader

# %%
loader = DeepFashionContrastiveLoader(split='train', debug=True, crop_margin=10, mode='color_mask_crop')

# %%
index = random.randint(0, len(loader)-1)
print(index)
x1, x2, y, metadata = loader.__getitem__(91634)
plt.imshow(x1)
plt.axis('off')
plt.show()
plt.imshow(x2)
plt.axis('off')
plt.show()
print("y", y)
print(metadata)
# Out:
# 135884
# y 1
# {'x1id': '056900_item2', 'x1groupid': '4501_1', 'x2id': '056904_item2', 'x2groupid': ('4501_1',), 'same_class': True}

# %%
from data_loader import DeepFashionContrastiveLoader
loader = DeepFashionContrastiveLoader(split='train', debug=True, crop_margin=10, mode='grayscale_mask')

# %%
index = random.randint(0, len(loader)-1)
print(index)
x1, x2, y, metadata = loader.__getitem__(276745)
print(y)
# plt.imshow(x1)
# plt.show()
# plt.imshow(x2)
# plt.show()
# print("y", y)
# print(metadata)
plt.imshow(x1[:, :, 0], cmap='gray')
plt.axis('off')
plt.show()
plt.imshow(x1[:, :, 2], cmap='gray')
plt.axis('off')
plt.show()
plt.imshow(x2[:, :, 0], cmap='gray')
plt.axis('off')
plt.show()
plt.imshow(x2[:, :, 2], cmap='gray')
plt.axis('off')
plt.show()
# Out:
# 102016
# 0

# %%
from data_loader import DeepFashionContrastiveLoader
loader = DeepFashionContrastiveLoader(split='train', debug=True, crop_margin=10, mode='color_mask_crop', one_sample_only=True)

# %%
x = loader.__getitem__(2)
x.shape
# Out:
# returning only one sample
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-213-7d2c082b1d3a> in <module>
#       1 x = loader.__getitem__(2)
# ----> 2 x.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
x[1].shape
# Out:
# (790, 468, 3)
