# %%
# %load ~/.firstcell.py
# %load_ext autoreload
# %autoreload 2

import json
import pandas as pd
import numpy as np 
from PIL import Image
import matplotlib.pyplot as plt 
import cv2
import os 
import sys
import csv
from IPython.display import Video, HTML

sys.path.insert(0, os.path.expanduser("~"))
from python_helpers import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import random
from data_loader import DeepFashionContrastiveLoader

# %%
loader = DeepFashionContrastiveLoader(split='train', debug=True, crop_margin=10, mode='color_mask_crop')

# %%
x1, x2, y, metadata = loader.__getitem__(0)
plt.imshow(x1)
plt.show()
plt.imshow(x2)
plt.show()
print("y", y)
print(metadata)
# Out:
# y 0
# {'x1id': '000001_item1', 'x2id': '097881_item2', 'x1groupid': '1_1', 'x2groupid': '7743_0', 'same_class': False}

# %%
from data_loader import DeepFashionContrastiveLoader
loader = DeepFashionContrastiveLoader(split='train', debug=True, crop_margin=10, mode='grayscale_mask')

# %%
x1, x2, y, metadata = loader.__getitem__(2)
# plt.imshow(x1)
# plt.show()
# plt.imshow(x2)
# plt.show()
# print("y", y)
# print(metadata)
plt.imshow(x1[:, :, 0], cmap='gray')
plt.show()
plt.imshow(x1[:, :, 2], cmap='gray')
plt.show()
plt.imshow(x2[:, :, 0], cmap='gray')
plt.show()
plt.imshow(x2[:, :, 2], cmap='gray')
plt.show()
# Out:
# image shape (832, 468, 3)
# gs image shape (832, 468, 3)
# mask shape (832, 468, 1)
# inp shape (832, 468, 3)
# image shape (1066, 800, 3)
# gs image shape (1066, 800, 3)
# mask shape (1066, 800, 1)
# inp shape (1066, 800, 3)

# %%
from data_loader import DeepFashionContrastiveLoader
loader = DeepFashionContrastiveLoader(split='train', debug=True, crop_margin=10, mode='color_mask_crop', one_sample_only=True)

# %%
x = loader.__getitem__(2)
x.shape
# Out:
# returning only one sample
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-213-7d2c082b1d3a> in <module>
#       1 x = loader.__getitem__(2)
# ----> 2 x.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
x[1].shape
# Out:
# (790, 468, 3)
