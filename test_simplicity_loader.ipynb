# %%
# %load ~/.firstcell.py
# %load_ext autoreload
# %autoreload 2

import json
import pandas as pd
import numpy as np 
from PIL import Image
import matplotlib.pyplot as plt 
import cv2
import os 
import sys
import csv
from IPython.display import Video, HTML
import random

sys.path.insert(0, os.path.expanduser("~"))
from python_helpers import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data_loader import SimplicityContrastiveLoader

# %%
dl = SimplicityContrastiveLoader()
len(dl)
# Out:
# Mode natural_image
# 1301

# %%
idx = random.randint(0, 1302)
print(idx)
img, ld, y = dl[idx]
print("same_class", bool(y))
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.axis('off')
plt.show()
plt.figure(figsize=(10,10))
plt.imshow(ld)
plt.axis('off')
plt.show()
# Out:
# 1116
# same_class False
